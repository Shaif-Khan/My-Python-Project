# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\mdfai\Downloads\Groceries_dataset.csv")
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
df.describe()
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
df.shape
# Out:
# (38765, 3)

# %%
df.columns
# Out:
# Index(['Member_number', 'Date', 'itemDescription'], dtype='object')

# %%
df['itemDescription'].value_counts().sort_values(ascending=False)
# Out:
# itemDescription
# whole milk               2502
# other vegetables         1898
# rolls/buns               1716
# soda                     1514
# yogurt                   1334
#                          ...
# rubbing alcohol             5
# bags                        4
# baby cosmetics              3
# kitchen utensil             1
# preservation products       1
# Name: count, Length: 167, dtype: int64

# %%
df['Member_number'].value_counts().sort_values(ascending=False)
# Out:
# Member_number
# 3180    36
# 3050    33
# 2051    33
# 3737    33
# 2625    31
#         ..
# 1673     2
# 4980     2
# 2841     2
# 3367     2
# 2417     2
# Name: count, Length: 3898, dtype: int64

# %%
sns.countplot(data=df,x='Member_number')
plt.title("Count of Member Number")
plt.figure(figsize=(15,5))

# %%
sns.countplot(data=df,x='Date',color='olive')
plt.title("Count of Date")
plt.figure(figsize=(15,5))

# %%
sns.countplot(data=df,x='itemDescription',color='purple')
plt.title("Count of Item Description")
plt.figure(figsize=(15,5))

# %%
l=df['itemDescription'].value_counts().sort_values(ascending=False)[:10]

# %%
l
# Out:
# itemDescription
# whole milk          2502
# other vegetables    1898
# rolls/buns          1716
# soda                1514
# yogurt              1334
# root vegetables     1071
# tropical fruit      1032
# bottled water        933
# sausage              924
# citrus fruit         812
# Name: count, dtype: int64

# %%
ax=sns.barplot(l.values,color='cyan')
plt.title("Maximum Sales of Top 10 Products") 
ax.bar_label(ax.containers[0])
plt.show()

# %%
ax=sns.barplot(l.index,color='cyan')
plt.title("Indexing of Top 10 Products")
ax.bar_label(ax.containers[0])
plt.show()

# %%
date=df['Date'].value_counts().sort_values(ascending=False)[:10]
date
# Out:
# Date
# 21-01-2015    96
# 21-07-2015    93
# 29-11-2015    92
# 08-08-2015    92
# 30-04-2015    91
# 28-08-2014    88
# 26-03-2015    88
# 30-09-2015    87
# 19-06-2015    85
# 16-05-2015    85
# Name: count, dtype: int64

# %%
ax=sns.barplot(date.values,color='yellow')
plt.title("Maximum Sales by Top 10 Date  ") 
ax.bar_label(ax.containers[0])
plt.show()

# %%
ax=sns.barplot(date.index,color='yellow')
plt.title("Maximum Top 10 Sales Date ") 
ax.bar_label(ax.containers[0])
plt.show()

# %%
member=df['Member_number'].value_counts().sort_values(ascending=False)[:10]
member
# Out:
# Member_number
# 3180    36
# 3050    33
# 2051    33
# 3737    33
# 2625    31
# 3915    31
# 2433    31
# 2271    31
# 3872    30
# 2394    29
# Name: count, dtype: int64

# %%
ax=sns.barplot(member.values,color='olive')
plt.title(" Top 10 Maximum Number of Members   ") 
ax.bar_label(ax.containers[0])
plt.show()

# %%
ax=sns.barplot(member.index,color='olive')
plt.title("Number of Top 10 Maximum Members  ") 
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# #Apriori Algorithm

# %%
pip install mlxtend
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.4 MB 326.8 kB/s eta 0:00:05
#    --- ------------------------------------ 0.1/1.4 MB 722.1 kB/s eta 0:00:02
#    --------- ------------------------------ 0.3/1.4 MB 1.6 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 2.0 MB/s eta 0:00:01
#    -------------------------- ------------- 0.9/1.4 MB 3.1 MB/s eta 0:00:01
#    --------------------------- ------------ 0.9/1.4 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.3 MB/s eta 0:00:00
# ...

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df['Quantity']=1

# %%
df
# Out:
#        Member_number        Date        itemDescription  Quantity
# 0               1808  21-07-2015         tropical fruit         1
# 1               2552  05-01-2015             whole milk         1
# 2               2300  19-09-2015              pip fruit         1
# 3               1187  12-12-2015       other vegetables         1
# 4               3037  01-02-2015             whole milk         1
# ...              ...         ...                    ...       ...
# 38760           4471  08-10-2014          sliced cheese         1
# 38761           2022  23-02-2014                  candy         1
# 38762           1097  16-04-2014               cake bar         1
# 38763           1510  03-12-2014  fruit/vegetable juice         1
# 38764           1521  26-12-2014               cat food         1
#
# [38765 rows x 4 columns]

# %%
transactions=df.groupby(['Member_number','itemDescription']).sum().unstack().reset_index().set_index('Member_number')

# %%
transactions
# Out:
#                                  Date                            \
# itemDescription Instant food products UHT-milk abrasive cleaner
# Member_number
# 1000                              NaN      NaN              NaN
# 1001                              NaN      NaN              NaN
# 1002                              NaN      NaN              NaN
# 1003                              NaN      NaN              NaN
# 1004                              NaN      NaN              NaN
# ...                               ...      ...              ...
# 4996                              NaN      NaN              NaN
# 4997                              NaN      NaN              NaN
# 4998                              NaN      NaN              NaN
# 4999                              NaN      NaN              NaN
# 5000                              NaN      NaN              NaN
#
#                                                                     \
# ...

# %%
transactions=transactions.fillna(0)

# %%
transactions
# Out:
#                                  Date                            \
# itemDescription Instant food products UHT-milk abrasive cleaner
# Member_number
# 1000                                0        0                0
# 1001                                0        0                0
# 1002                                0        0                0
# 1003                                0        0                0
# 1004                                0        0                0
# ...                               ...      ...              ...
# 4996                                0        0                0
# 4997                                0        0                0
# 4998                                0        0                0
# 4999                                0        0                0
# 5000                                0        0                0
#
#                                                                     \
# ...
